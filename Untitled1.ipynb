# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\IFC-94\Downloads\car_data.csv")

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data["Selling_Price"].min()
# Out:
# 0.1

# %%
data.shape
# Out:
# (301, 9)

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data["Car_Name"].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
# ...

# %%
unique_car_count = len(data["Car_Name"].unique())
print(unique_car_count)
# Out:
# 98

# %%
cng_count = (data["Fuel_Type"] == "CNG").sum()
print(cng_count)
# Out:
# 2

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
print(data.Fuel_Type.value_counts())
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
data.Fuel_Type.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
transmission_count = data["Transmission"].value_counts()

print(transmission_count)
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
Owner_count = data["Owner"].value_counts()

print(Owner_count)
# Out:
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
car_count = data["Car_Name"].value_counts()
car_count
# Out:
# Car_Name
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: count, Length: 98, dtype: int64

# %%
import matplotlib.pyplot as plt

car_count = data["Car_Name"].value_counts()

plt.figure(figsize=(24, 24)) 
car_count.plot(kind="bar", color='skyblue')

plt.title('Count of Cars by Car Name')
plt.xlabel('Car Name')
plt.ylabel('Count')
plt.xticks(rotation=90) 
plt.show()

# %%
unique_car_count = data["Car_Name"].nunique()

print(f' {unique_car_count}')
# Out:
#  98

# %%
import seaborn as sns
fig_dims = (12, 20)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(y = data.Car_Name,ax=ax, data = data)
# Out:
# <Axes: xlabel='count', ylabel='Car_Name'>

# %%
data2=pd.read_csv(r"C:\Users\IFC-94\Downloads\WalmartSalesData.csv")

# %%
data2
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#impoting seaborn library
import seaborn as sns

# displaying plots in jupyter notebook
# %matplotlib inline

# %%
data2.describe
# Out:
# <bound method NDFrame.describe of       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
tips = sns.load_dataset('tips')

# %%
tips.Head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13804\1527533771.py in ?()
# ----> 1 tips.Head()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Head'

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# # From which manufacturing year to which manufacturing year vehicles are present in this data ?

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# ## 2003 to 2018

# %% [markdown]
# # What is the lowest price to which a vehicle is sold ?

# %% [markdown]
# ## 0.320000

# %% [markdown]
# # What is the highest price to which a vehicle is sold ?

# %% [markdown]
# ## 92.600000

# %% [markdown]
# # How many records are there in this data ?

# %%
data.shape
# Out:
# (301, 9)

# %% [markdown]
# # Are there any missing records in this data ?

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# # How many different vehicles are present in this data ?

# %%
unique_car_count = len(data["Car_Name"].unique())
print(unique_car_count)
# Out:
# 98

# %% [markdown]
# # Which is the most sold vehicle in this data ?

# %%
most_sold_vehicle = data['Car_Name'].value_counts().idxmax()

most_sold_vehicle_count = data['Car_Name'].value_counts().max()

print(f"The most sold vehicle is: {most_sold_vehicle}")
print(f"It was sold {most_sold_vehicle_count} times.")
# Out:
# The most sold vehicle is: city
# It was sold 26 times.

# %% [markdown]
# # Does the database include any CNG vehicle ? If yes how many of them are there ?

# %%
cng_count = (data["Fuel_Type"] == "CNG").sum()
print(cng_count)
# Out:
# 2

# %% [markdown]
# ## yes 2

# %%
data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %% [markdown]
# # How many vehicles here are for sell from Individuals directly ?

# %%
individual_sales_count = data[data['Seller_Type'] == 'Individual'].shape[0]

print(f"Number of vehicles being sold by individuals: {individual_sales_count}")
# Out:
# Number of vehicles being sold by individuals: 106

# %%
auto_transmission_count = data[data['Transmission'] == 'Auto'].shape[0]

if auto_transmission_count > 0:
    print(f"The database contains {auto_transmission_count} vehicles with automatic transmission.")
else:
    print("No vehicles with automatic transmission are found in the database.")
# Out:
# No vehicles with automatic transmission are found in the database.

# %% [markdown]
# # How many single person owned vehicles are there in this database ?

# %%
# Count how many vehicles have only one owner
single_owner_vehicles_count = data[data['Owner'] == 1].shape[0]

print(f"Number of single-owner vehicles: {single_owner_vehicles_count}")
# Out:
# Number of single-owner vehicles: 10

# %% [markdown]
# # Which is the most and least cost depreciated vehicle in data ?

# %%
data['Depreciation'] = data['Present_Price'] - data['Selling_Price']

most_depreciated_vehicle = data.loc[data['Depreciation'].idxmax()]
least_depreciated_vehicle = data.loc[data['Depreciation'].idxmin()]

print(f"Most cost depreciated vehicle: {most_depreciated_vehicle['Car_Name']} with depreciation of {most_depreciated_vehicle['Depreciation']}")
print(f"Least cost depreciated vehicle: {least_depreciated_vehicle['Car_Name']} with depreciation of {least_depreciated_vehicle['Depreciation']}")
# Out:
# Most cost depreciated vehicle: land cruiser with depreciation of 57.599999999999994
# Least cost depreciated vehicle: Honda Activa 4G with depreciation of 0.030000000000000027

# %% [markdown]
# # Which brands of vehicles are less affected by cost depreciation?

# %%
data['Brand'] = data['Car_Name'].apply(lambda x: x.split()[0]) 

avg_depreciation_per_brand = data.groupby('Brand')['Depreciation'].mean().sort_values()

print(f"Brands less affected by depreciation: {avg_depreciation_per_brand.head(10)}")
# Out:
# Brands less affected by depreciation: Brand
# UM          0.120000
# Activa      0.183333
# TVS         0.242750
# Mahindra    0.250000
# Yamaha      0.258750
# Hero        0.265200
# Honda       0.318824
# Suzuki      0.330000
# Bajaj       0.334400
# Royal       0.423529
# Name: Depreciation, dtype: float64

# %% [markdown]
# # Are there any factors that affect the cost depreciation?

# %%
corr_with_depreciation = data.corr()['Depreciation'].sort_values()

print("Factors affecting cost depreciation:")
print(corr_with_depreciation)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[199], line 2
#       1 # Correlation between depreciation and other numeric factors
# ----> 2 corr_with_depreciation = data.corr()['Depreciation'].sort_values()
#       4 print("Factors affecting cost depreciation:")
#       5 print(corr_with_depreciation)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...

# %% [markdown]
# # Is it observable from data that selling price is affected by the age of the vehicle and distance driven?

# %%
data['Vehicle_Age'] = current_year - data['Year']

corr_with_selling_price = data[['Selling_Price', 'Vehicle_Age', 'Kms_Driven']].corr()

print("Correlation between selling price, vehicle age, and distance driven:")
print(corr_with_selling_price)
# Out:
# Correlation between selling price, vehicle age, and distance driven:
#                Selling_Price  Vehicle_Age  Kms_Driven
# Selling_Price       1.000000    -0.236141    0.029187
# Vehicle_Age        -0.236141     1.000000    0.524342
# Kms_Driven          0.029187     0.524342    1.000000

# %% [markdown]
# # Can we get an idea about the newest vehicles (i.e., after 2014 manufactured)?

# %%
newest_vehicles = data[data['Year'] > 2014]

print(f"Number of newest vehicles (after 2014): {newest_vehicles.shape[0]}")
# Out:
# Number of newest vehicles (after 2014): 147

# %% [markdown]
# # Do you find any deal in two-wheelers that exceeded the general expectation? Can you find the reason for it?

# %%
import numpy as np


two_wheelers['Depreciation'] = two_wheelers['Present_Price'] - two_wheelers['Selling_Price']


Q1 = two_wheelers['Selling_Price'].quantile(0.25)
Q3 = two_wheelers['Selling_Price'].quantile(0.75)
IQR = Q3 - Q1


outliers = two_wheelers[two_wheelers['Selling_Price'] > (Q3 + 1.5 * IQR)]

print(f"Outlier deals in two-wheelers that exceeded general expectations: {outliers[['Car_Name', 'Selling_Price', 'Present_Price']]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[208], line 4
#       1 import numpy as np
# ----> 4 two_wheelers['Depreciation'] = two_wheelers['Present_Price'] - two_wheelers['Selling_Price']
#       7 Q1 = two_wheelers['Selling_Price'].quantile(0.25)
#       8 Q3 = two_wheelers['Selling_Price'].quantile(0.75)
#
# NameError: name 'two_wheelers' is not defined

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner  \
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000
#
#        Depreciation  Vehicle_Age
# count    301.000000   301.000000
# mean       2.967176    11.372093
# std        4.828771     2.891554
# min        0.030000     7.000000
# 25%        0.390000     9.000000
# 50%        1.640000    11.000000
# 75%        3.350000    13.000000
# ...

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  Depreciation  Brand  Vehicle_Age
# 0      Dealer       Manual      0          2.24   ritz           11
# 1      Dealer       Manual      0          4.79    sx4           12
# 2      Dealer       Manual      0          2.60   ciaz            8
# 3      Dealer       Manual      0          1.30  wagon           14
# 4      Dealer       Manual      0          2.27  swift           11

# %%
two_wheelers = data[data['Car_Name'].str.contains('bike|scooter', case=False, na=False)]  

two_wheelers['Depreciation'] = two_wheelers['Present_Price'] - two_wheelers['Selling_Price']

Q1 = two_wheelers['Selling_Price'].quantile(0.25)
Q3 = two_wheelers['Selling_Price'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = two_wheelers[(two_wheelers['Selling_Price'] < lower_bound) | (two_wheelers['Selling_Price'] > upper_bound)]

print(outliers)
# Out:
# Empty DataFrame
# Columns: [Car_Name, Year, Selling_Price, Present_Price, Kms_Driven, Fuel_Type, Seller_Type, Transmission, Owner, Depreciation, Brand, Vehicle_Age]
# Index: []

# %% [markdown]
# # Can we find out data of only cars from this data ?
